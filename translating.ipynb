# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
# These are my own functions that help clean the data

def search_columns_for_substring(columns, substring):
    return [col for col in columns if substring in col]

# this function counts how many empty values are in each column for a data set (use this after the drop col function to verify)
def count_nans_in_dataframe(df):
    nan_counts = df.isna().sum()
    return pd.DataFrame({'Column': nan_counts.index, 'NaN Count': nan_counts.values})

# this function drops columns that do not meet the minimum threshold
# if by="count" then drop columns that don't have at least that many populated fields
    # ie. by_val=100 drops columns that have less than 100 populated rows
# if by="prop" then drop columns that don't have at least by_val% populated rows
    # ie. by_val=0.05 drops columns that aren't at least 5% populated
# if by="field" then drop columns that have more missing values than the columns specified
    # ie. by_val="Last_Device_Array.anv" will keep Last_Device_Array.anv but drop any cols that have more missing values than Last_Device_Array.anv
def drop_columns_with_fewer_nans(df, by="prop", by_val="0.05"):
    if by == "count":
        threshold = float(by_val)
    elif by == "prop": threshold = round(df.shape[0]*float(by_val))
    elif by == "field": threshold = df.shape[0]-df[by_val].isna().sum()
    cols_to_drop = []
    for col in df.columns:
        if df[col].isna().sum() > df.shape[0]-threshold:
            cols_to_drop.append(col)
    df = df.drop(cols_to_drop, axis=1)
    return df

# %%
# Load the war dataset
file_path = '/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall 2023/STAT 386/ST386_Final_Project/Scraped_Data/Viking_war_artifacts.csv'
war_df = pd.read_csv(file_path)
war_df['Extra Details'] = war_df['Extra Details'].map(json.loads)
war_artifacts_exploded = pd.json_normalize(war_df.to_dict(orient='records'))

# drop rows that are not at least 25% populated
cleaned_war_artifacts = drop_columns_with_fewer_nans(war_artifacts_exploded, "prop", 0.25)

cleaned_war_artifacts.head(5)
# Out:
#    Unnamed: 0 Föremålsbenämning Föremålsnr.  Förvärvsnr.  \
# 0           0             Spjut  371667_HST      34000.0
# 1           1             Spjut  371668_HST      34000.0
# 2           2  Svärd Petersen Y  263086_HST      34000.0
# 3           3    Tveeggat svärd  263468_HST      34000.0
# 4           4  Svärd Petersen Y  264449_HST          NaN
#
#            Andra nummer Material                 Plats Fornlämning  \
# 0   Undernummer: Bj 581     Järn  Björkö, Norr om Borg  L2017:1478
# 1   Undernummer: Bj 581     Järn  Björkö, Norr om Borg  L2017:1478
# 2  Undernummer: Bj 752B     Järn     Björkö, Hemlanden  L2017:1904
# 3   Undernummer: Bj 542     Järn  Björkö, Norr om Borg  L2017:1478
# 4           FID: 264449     Järn                   NaN         NaN
#
#           Socken Landskap  ... Extra Details.Historisk plats  \
# 0  Adelsö socken  Uppland  ...          Birka, Adelsö socken
# 1  Adelsö socken  Uppland  ...          Birka, Adelsö socken
# 2  Adelsö socken  Uppland  ...          Birka, Adelsö socken
# 3  Adelsö socken  Uppland  ...          Birka, Adelsö socken
# 4            NaN      NaN  ...                           NaN
#
#   Extra Details.Förvärvsnummer  \
# 0                        34000
# 1                        34000
# 2                        34000
# 3                        34000
# 4                          NaN
#
#                      Extra Details.Omnämns i katalog  \
# 0  http://catview.historiska.se/catview/CatViewSe...
# 1  http://catview.historiska.se/catview/CatViewSe...
# 2  http://catview.historiska.se/catview/CatViewSe...
# 3  http://catview.historiska.se/catview/CatViewSe...
# 4                                                NaN
#
#   Extra Details.Förvärvsmetod  \
# 0                         KML
# 1                         KML
# 2                         KML
# 3                         KML
# 4                         NaN
#
#                              Extra Details.Fyndplats  \
# 0  Plats: Björkö, Norr om Borg, Fornlämning: L201...
# 1  Plats: Björkö, Norr om Borg, Fornlämning: L201...
# 2  Plats: Björkö, Hemlanden, Fornlämning: L2017:1...
# 3  Plats: Björkö, Norr om Borg, Fornlämning: L201...
# 4                                      Land: Sverige
#
#                 Extra Details.Arkeologisk kontext Extra Details.Kontextnamn  \
# 0            Kammargrav, Grav, Flatmarksgrav: 581                    Bj 581
# 1            Kammargrav, Grav, Flatmarksgrav: 581                    Bj 581
# 2                     Kammargrav, Grav, Hög: 752B                   Bj 752B
# 3  Kammargrav, Grav, Obekant yttre gravskick: 542                    Bj 542
# 4                                             NaN                       NaN
#
#   Extra Details.Undersökare Extra Details.Undersökningsår  \
# 0           Stolpe, Hjalmar                          1878
# 1           Stolpe, Hjalmar                          1878
# 2           Stolpe, Hjalmar                          1879
# 3           Stolpe, Hjalmar                          1878
# 4                       NaN                           NaN
#
#   Extra Details.Antal fragment
# 0                          NaN
# 1                          NaN
# 2                            7
# 3                            2
# 4                            1
#
# [5 rows x 36 columns]

# %%
# Load the era dataset
file_path = '/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall 2023/STAT 386/ST386_Final_Project/Scraped_Data/Viking_era_artifacts.csv'
era_df = pd.read_csv(file_path)
era_df['Extra Details'] = era_df['Extra Details'].map(json.loads)
era_artifacts_exploded = pd.json_normalize(era_df.to_dict(orient='records'))

# drop rows that are not at least 25% populated
cleaned_era_artifacts = drop_columns_with_fewer_nans(era_artifacts_exploded, "prop", 0.25)

cleaned_era_artifacts.head(5)
# Out:
#    Unnamed: 0 Föremålsbenämning      Föremålsnr.          Förvärvsnr.  \
# 0           0  yxa med skafthål  TESTPOST_SIS_01  TESTPOST_SIS_ACC_01
# 1           1              Mynt         2720_SKO                  NaN
# 2           2             Svärd        13389_SKO                  NaN
# 3           3          Skäggyxa        13391_SKO                  NaN
# 4           4  Svärd Petersen H        13394_SKO                  NaN
#
#                 Andra nummer  Material  \
# 0  Nr 1867: 17:17:17:896:783  Päronträ
# 1                        NaN    Silver
# 2                        NaN      Järn
# 3                        NaN      Järn
# 4                        NaN      Järn
#
#                                                Plats  \
# 0  Ohio, San Juan County, Reapture Creek, Fagersk...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                  Fornlämning Socken Landskap  ... Extra Details.Tidsperiod  \
# 0  TESTPOST_SIS_GEO_FORNL_02    NaN      NaN  ...                 1700-tal
# 1                        NaN    NaN      NaN  ...                      NaN
# 2                        NaN    NaN      NaN  ...               Vikingatid
# 3                        NaN    NaN      NaN  ...                      NaN
# 4                        NaN    NaN      NaN  ...               Vikingatid
#
#                     Extra Details.Tillverkningsplats  \
# 0  Baoussé-Roussé, Menton (Tillverkningsplats not...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Extra Details.Tillverkare Extra Details.Föremålsnummer  \
# 0  Ablancourt, Nicolas Perrot d' (Tillverkare)              TESTPOST_SIS_01
# 1                                          NaN                     2720_SKO
# 2                                          NaN                    13389_SKO
# 3                                          NaN                    13391_SKO
# 4                                          NaN                    13394_SKO
#
#   Extra Details.Andra nummer  \
# 0  Nr 1867: 17:17:17:896:783
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#                             Extra Details.Litteratur  \
# 0  Naturligt åldrat papper. Rapport nr 4\t2. Sven...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Extra Details.Förvärvsnummer       Extra Details.Omnämns i katalog  \
# 0          TESTPOST_SIS_ACC_01  https://historiska.se/utstallningar/
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                                   NaN
#
#   Extra Details.Förvärvsmetod  \
# 0                        Gåva
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                              Extra Details.Fyndplats
# 0  Plats: Ohio, San Juan County, Reapture Creek, ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 32 columns]

# %%
# Load the trade dataset
file_path = '/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall 2023/STAT 386/ST386_Final_Project/Scraped_Data/Viking_trade_artifacts.csv'
trade_df = pd.read_csv(file_path)
trade_df['Extra Details'] = trade_df['Extra Details'].map(json.loads)
trade_artifacts_exploded = pd.json_normalize(trade_df.to_dict(orient='records'))

# drop rows that are not at least 25% populated
cleaned_trade_artifacts = drop_columns_with_fewer_nans(trade_artifacts_exploded, "prop", 0.25)

cleaned_trade_artifacts.head(5)
# Out:
#    Unnamed: 0 Föremålsbenämning Föremålsnr.  Förvärvsnr.         Andra nummer  \
# 0           0      Bipolär vikt  371770_HST      16835.0       Undernummer: 2
# 1           1              Vikt  106523_HST      34000.0  Undernummer: Bj 977
# 2           2         Balansvåg  107068_HST      12426.0    Undernummer: M:IV
# 3           3         Mynthänge      46_HST      33758.0      Undernummer: 50
# 4           4              Barr      50_HST      33758.0      Undernummer: 57
#
#       Material              Plats Fornlämning            Socken  Landskap  \
# 0  Brons, Järn          Tystebols         NaN  Stenkyrka socken   Gotland
# 1        Brons  Björkö, Hemlanden  L2017:1904     Adelsö socken   Uppland
# 2        Brons              Rösta   L1945:291         Ås socken  Jämtland
# 3       Silver          Spillings  L1976:7626      Othem socken   Gotland
# 4       Silver          Spillings  L1976:7626      Othem socken   Gotland
#
#    ...                        Extra Details.Andra nummer  \
# 0  ...                       Undernummer: 2  FID: 371770
# 1  ...  Undernummer: Bj 977  Fyndnummer: 62  FID: 106523
# 2  ...                    Undernummer: M:IV  FID: 107068
# 3  ...          Undernummer: 50  Fyndnummer: 43  FID: 46
# 4  ...          Undernummer: 57  Fyndnummer: 46  FID: 50
#
#   Extra Details.Förvärvsnummer  \
# 0                        16835
# 1                        34000
# 2                        12426
# 3                        33758
# 4                        33758
#
#                      Extra Details.Omnämns i katalog  \
# 0  http://catview.historiska.se/catview/CatViewSe...
# 1  http://catview.historiska.se/catview/CatViewSe...
# 2  http://catview.historiska.se/catview/CatViewSe...
# 3  http://catview.historiska.se/catview/CatViewSe...
# 4  http://catview.historiska.se/catview/CatViewSe...
#
#                              Extra Details.Fyndplats  \
# 0  Plats: Tystebols, Socken: Stenkyrka socken, Ko...
# 1  Plats: Björkö, Hemlanden, Fornlämning: L2017:1...
# 2  Plats: Rösta, Fornlämning: L1945:291, Socken: ...
# 3  Plats: Spillings, Fornlämning: L1976:7626, Fas...
# 4  Plats: Spillings, Fornlämning: L1976:7626, Fas...
#
#   Extra Details.Historisk plats Extra Details.Förvärvsmetod  \
# 0                           NaN                         NaN
# 1          Birka, Adelsö socken                         KML
# 2                           NaN                         NaN
# 3                           NaN               KML (inlösen)
# 4                           NaN               KML (inlösen)
#
#   Extra Details.Arkeologisk kontext Extra Details.Kontextnamn  \
# 0                               NaN                       NaN
# 1        Kammargrav, Grav, Hög: 977                    Bj 977
# 2                        Grav: M:IV                       NaN
# 3                      Skattfynd: 1           Spillingskatten
# 4                      Skattfynd: 1           Spillingskatten
#
#   Extra Details.Undersökare Extra Details.Undersökningsår
# 0                       NaN                           NaN
# 1           Stolpe, Hjalmar                          1881
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
# [5 rows x 35 columns]

# %%
from googletrans import Translator, LANGUAGES

# Initialize the translator
translator = Translator()

# Function to translate text
def translate_text(text, src='sv', dest='en'):
    try:
        return translator.translate(text, src=src, dest=dest).text
    except Exception as e:
        # In case of an error, return original text
        return text

# Columns to translate
columns_to_translate = cleaned_war_artifacts.columns.to_list()

translated_war = []

# Translate the columns
for column in columns_to_translate:
    cleaned_war_artifacts[column] = cleaned_war_artifacts[column].apply(lambda x: translate_text(x) if isinstance(x, str) else x)

cleaned_war_artifacts.head(5)

# Save the translated dataframe to a new CSV file
cleaned_war_artifacts.to_csv('translated_viking_war_artifacts.csv', index=False)
# Out:
#    Unnamed: 0  Föremålsbenämning Föremålsnr.  Förvärvsnr.        Andra nummer  \
# 0           0              Spear  371667_hst      34000.0   Sub -code: BJ 581
# 1           1              Spear  371668_hst      34000.0   Sub -code: BJ 581
# 2           2  Sword Petersen Y.  263086_HST      34000.0  Sub -code: BJ 752B
# 3           3      Tveggat sword  263468_hst      34000.0   Sub -code: BJ 542
# 4           4  Sword Petersen Y.  264449_HST          NaN         FID: 264449
#
#   Material                  Plats Fornlämning         Socken Landskap  ...  \
# 0     Iron  Björkö, north of Borg  L2017:1478  Adelsö socken  Uppland  ...
# 1     Iron  Björkö, north of Borg  L2017:1478  Adelsö socken  Uppland  ...
# 2     Iron       Björkö, homeland  L2017:1904  Adelsö socken  Uppland  ...
# 3     Iron  Björkö, north of Borg  L2017:1478  Adelsö socken  Uppland  ...
# 4     Iron                    NaN         NaN            NaN      NaN  ...
#
#   Extra Details.Historisk plats Extra Details.Förvärvsnummer  \
# 0          Birka, Adelsö socken                        34000
# 1          Birka, Adelsö socken                        34000
# 2          Birka, Adelsö socken                        34000
# 3          Birka, Adelsö socken                        34000
# 4                           NaN                          NaN
#
#                      Extra Details.Omnämns i katalog  \
# 0  http://catview.historiska.se/catview/CatViewSe...
# 1  http://catview.historiska.se/catview/CatViewSe...
# 2  http://catview.historiska.se/catview/CatViewSe...
# 3  http://catview.historiska.se/catview/CatViewSe...
# 4                                                NaN
#
#   Extra Details.Förvärvsmetod  \
# 0                         KML
# 1                         KML
# 2                         KML
# 3                         KML
# 4                         NaN
#
#                              Extra Details.Fyndplats  \
# 0  Plats: Björkö, Norr om Borg, Fornlämning: L201...
# 1  Plats: Björkö, Norr om Borg, Fornlämning: L201...
# 2  Plats: Björkö, Hemlanden, Fornlämning: L2017:1...
# 3  Plats: Björkö, Norr om Borg, Fornlämning: L201...
# 4                                      Land: Sverige
#
#                 Extra Details.Arkeologisk kontext Extra Details.Kontextnamn  \
# 0            Kammargrav, Grav, Flatmarksgrav: 581                    Bj 581
# 1            Kammargrav, Grav, Flatmarksgrav: 581                    Bj 581
# 2                     Kammargrav, Grav, Hög: 752B                   Bj 752B
# 3  Kammargrav, Grav, Obekant yttre gravskick: 542                    Bj 542
# 4                                             NaN                       NaN
#
#   Extra Details.Undersökare Extra Details.Undersökningsår  \
# 0           Stolpe, Hjalmar                          1878
# 1           Stolpe, Hjalmar                          1878
# 2           Stolpe, Hjalmar                          1879
# 3           Stolpe, Hjalmar                          1878
# 4                       NaN                           NaN
#
#   Extra Details.Antal fragment
# 0                          NaN
# 1                          NaN
# 2                            7
# 3                            2
# 4                            1
#
# [5 rows x 36 columns]

# %%
# Columns to translate
columns_to_translate = cleaned_era_artifacts.columns.to_list()

# Translate the columns
for column in columns_to_translate:
    cleaned_era_artifacts[column] = cleaned_era_artifacts[column].apply(lambda x: translate_text(x) if isinstance(x, str) else x)

cleaned_era_artifacts.head(5)

# Save the translated dataframe to a new CSV file
cleaned_era_artifacts.to_csv('translated_viking_era_artifacts.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall 2023/STAT 386/ST386_Final_Project/translating.ipynb Cell 7 line 6
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> # Translate the columns
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> for column in columns_to_translate:
# ----> <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     cleaned_era_artifacts[column] = cleaned_era_artifacts[column].apply(lambda x: translate_text(x) if isinstance(x, str) else x)
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> cleaned_era_artifacts.head(5)
#      <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> # Save the translated dataframe to a new CSV file
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# /Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall 2023/STAT 386/ST386_Final_Project/translating.ipynb Cell 7 line 6
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> # Translate the columns
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> for column in columns_to_translate:
# ----> <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     cleaned_era_artifacts[column] = cleaned_era_artifacts[column].apply(lambda x: translate_text(x) if isinstance(x, str) else x)
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> cleaned_era_artifacts.head(5)
#      <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> # Save the translated dataframe to a new CSV file
#
# /Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall 2023/STAT 386/ST386_Final_Project/translating.ipynb Cell 7 line 9
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a> def translate_text(text, src='sv', dest='en'):
#       <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     try:
# ----> <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a>         return translator.translate(text, src=src, dest=dest).text
#      <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     except Exception as e:
#      <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a>         # In case of an error, return original text
#      <a href='vscode-notebook-cell:/Users/aly.milne/Library/CloudStorage/OneDrive-BrighamYoungUniversity/Fall%202023/STAT%20386/ST386_Final_Project/translating.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>         return text
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/googletrans/client.py:194, in Translator.translate(self, text, dest, src)
#     191         raise ValueError('invalid destination language')
#     193 origin = text
# --> 194 data, response = self._translate(text, dest, src)
#     196 token_found = False
#     197 square_bracket_counts = [0, 0]
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/googletrans/client.py:120, in Translator._translate(self, text, dest, src)
#     109 data = {
#     110     'f.req': self._build_rpc_request(text, dest, src),
#     111 }
#     112 params = {
#     113     'rpcids': RPC_ID,
#     114     'bl': 'boq_translate-webserver_20201207.13_p0',
#    (...)
#     118     'rt': 'c',
#     119 }
# --> 120 r = self.client.post(url, params=params, data=data)
#     122 if r.status_code != 200 and self.raise_Exception:
#     123     raise Exception('Unexpected status code "{}" from {}'.format(
#     124         r.status_code, self.service_urls))
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpx/_client.py:824, in Client.post(self, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     810 def post(
#     811     self,
#     812     url: URLTypes,
#    (...)
#     822     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     823 ) -> Response:
# --> 824     return self.request(
#     825         "POST",
#     826         url,
#     827         data=data,
#     828         files=files,
#     829         json=json,
#     830         params=params,
#     831         headers=headers,
#     832         cookies=cookies,
#     833         auth=auth,
#     834         allow_redirects=allow_redirects,
#     835         timeout=timeout,
#     836     )
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpx/_client.py:600, in Client.request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     575 def request(
#     576     self,
#     577     method: str,
#    (...)
#     588     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     589 ) -> Response:
#     590     request = self.build_request(
#     591         method=method,
#     592         url=url,
#    (...)
#     598         cookies=cookies,
#     599     )
# --> 600     return self.send(
#     601         request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602     )
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpx/_client.py:620, in Client.send(self, request, stream, auth, allow_redirects, timeout)
#     616 timeout = self.timeout if isinstance(timeout, UnsetType) else Timeout(timeout)
#     618 auth = self.build_auth(request, auth)
# --> 620 response = self.send_handling_redirects(
#     621     request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622 )
#     624 if not stream:
#     625     try:
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpx/_client.py:647, in Client.send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     644 if len(history) > self.max_redirects:
#     645     raise TooManyRedirects()
# --> 647 response = self.send_handling_auth(
#     648     request, auth=auth, timeout=timeout, history=history
#     649 )
#     650 response.history = list(history)
#     652 if not response.is_redirect:
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpx/_client.py:684, in Client.send_handling_auth(self, request, history, auth, timeout)
#     682 request = next(auth_flow)
#     683 while True:
# --> 684     response = self.send_single_request(request, timeout)
#     685     if auth.requires_response_body:
#     686         response.read()
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpx/_client.py:714, in Client.send_single_request(self, request, timeout)
#     705 transport = self.transport_for_url(request.url)
#     707 try:
#     708     (
#     709         http_version,
#     710         status_code,
#     711         reason_phrase,
#     712         headers,
#     713         stream,
# --> 714     ) = transport.request(
#     715         request.method.encode(),
#     716         request.url.raw,
#     717         headers=request.headers.raw,
#     718         stream=request.stream,
#     719         timeout=timeout.as_dict(),
#     720     )
#     721 except HTTPError as exc:
#     722     # Add the original request to any HTTPError unless
#     723     # there'a already a request attached in the case of
#     724     # a ProxyError.
#     725     if exc._request is None:
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:152, in SyncConnectionPool.request(self, method, url, headers, stream, timeout)
#     149         logger.trace("reuse connection=%r", connection)
#     151 try:
# --> 152     response = connection.request(
#     153         method, url, headers=headers, stream=stream, timeout=timeout
#     154     )
#     155 except NewConnectionRequired:
#     156     connection = None
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_sync/connection.py:78, in SyncHTTPConnection.request(self, method, url, headers, stream, timeout)
#      74 assert self.connection is not None
#      75 logger.trace(
#      76     "connection.request method=%r url=%r headers=%r", method, url, headers
#      77 )
# ---> 78 return self.connection.request(method, url, headers, stream, timeout)
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_sync/http2.py:118, in SyncHTTP2Connection.request(self, method, url, headers, stream, timeout)
#     116     self.streams[stream_id] = h2_stream
#     117     self.events[stream_id] = []
# --> 118     return h2_stream.request(method, url, headers, stream, timeout)
#     119 except Exception:
#     120     self.max_streams_semaphore.release()
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_sync/http2.py:292, in SyncHTTP2Stream.request(self, method, url, headers, stream, timeout)
#     289     self.send_body(stream, timeout)
#     291 # Receive the response.
# --> 292 status_code, headers = self.receive_response(timeout)
#     293 reason_phrase = get_reason_phrase(status_code)
#     294 stream = SyncByteStream(
#     295     iterator=self.body_iter(timeout), close_func=self._response_closed
#     296 )
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_sync/http2.py:344, in SyncHTTP2Stream.receive_response(self, timeout)
#     340 """
#     341 Read the response status and headers from the network.
#     342 """
#     343 while True:
# --> 344     event = self.connection.wait_for_event(self.stream_id, timeout)
#     345     if isinstance(event, h2.events.ResponseReceived):
#     346         break
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_sync/http2.py:197, in SyncHTTP2Connection.wait_for_event(self, stream_id, timeout)
#     195 with self.read_lock:
#     196     while not self.events[stream_id]:
# --> 197         self.receive_events(timeout)
#     198 return self.events[stream_id].pop(0)
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_sync/http2.py:204, in SyncHTTP2Connection.receive_events(self, timeout)
#     200 def receive_events(self, timeout: TimeoutDict) -> None:
#     201     """
#     202     Read some data from the network, and update the H2 state.
#     203     """
# --> 204     data = self.socket.read(self.READ_NUM_BYTES, timeout)
#     205     events = self.h2_state.receive_data(data)
#     206     for event in events:
#
# File /usr/local/anaconda3/envs/stat386/lib/python3.10/site-packages/httpcore/_backends/sync.py:62, in SyncSocketStream.read(self, n, timeout)
#      60 with map_exceptions(exc_map):
#      61     self.sock.settimeout(read_timeout)
# ---> 62     return self.sock.recv(n)
#
# KeyboardInterrupt:

# %%
# Columns to translate
columns_to_translate = cleaned_trade_artifacts.columns.to_list()

# Translate the columns
for column in columns_to_translate:
    cleaned_trade_artifacts[column] = cleaned_trade_artifacts[column].apply(lambda x: translate_text(x) if isinstance(x, str) else x)

cleaned_trade_artifacts.head(5)

# Save the translated dataframe to a new CSV file
cleaned_trade_artifacts.to_csv('translated_viking_trade_artifacts.csv', index=False)
